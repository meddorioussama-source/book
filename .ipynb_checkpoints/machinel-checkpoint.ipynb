# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_original =pd.read_csv("titanic.csv")
df =df_original.copy()

# %%
df.head ()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head ().T
# Out:
#                                    0  \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                              1  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %% [markdown]
# what does df do :
# df extracts our folder
# and head takes the first 5 values

# %%
df.info()   #the type of every variable in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()                   #somthing
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape    # the shape of our matrix
# Out:
# (891, 12)

# %%
df.columns         #the data in each column
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.replace(' ','_') #we make everything into lower case and we remove all spaces

# %%
df.head().T
# Out:
#                                    0  \
# passengerid                        1
# survived                           0
# pclass                             3
# name         Braund, Mr. Owen Harris
# sex                             male
# age                             22.0
# sibsp                              1
# parch                              0
# ticket                     A/5 21171
# fare                            7.25
# cabin                            NaN
# embarked                           S
#
#                                                              1  \
# passengerid                                                  2
# survived                                                     1
# pclass                                                       1
# name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                     female
# age                                                       38.0
# ...

# %%
print(df['name'].head(10).tolist())
# Out:
# ['Braund, Mr. Owen Harris', 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'Heikkinen, Miss. Laina', 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'Allen, Mr. William Henry', 'Moran, Mr. James', 'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard', 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)', 'Nasser, Mrs. Nicholas (Adele Achem)']

# %%
def extract_title(name):
    return name.split(',')[1].split('.')[0].strip()

df['title']=df['name'].apply(extract_title)

# %%
df['title'].value_counts()
# Out:
# title
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Col               2
# Mlle              2
# Major             2
# Ms                1
# Mme               1
# Don               1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,3))
df['title'].value_counts().plot(kind='bar')
plt.title('distribution of titles')
plt.xlabel('title')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['title']=df['title'].replace('[lady,rev,col,mlle,major,ms,sir,jonkheer]','other')#

# %%
df['familysize']=df['parch'] + df['sibsp'] + 1

# %%
df['familysize'].value_counts()
# Out:
# familysize
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: count, dtype: int64

# %%
bins=[0,1,4,float('inf')]
labels=['alone','small','large']
df['familygroup']=pd.cut(df['familysize'],bins=bins,labels=labels)

# %%
df['familygroup'].value_counts()
# Out:
# familygroup
# alone    537
# small    292
# large     62
# Name: count, dtype: int64

# %%
del df['familysize']
del df['parch']
del df['sibsp']
del df['familygroup']

# %%
df.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'ticket',
#        'fare', 'cabin', 'embarked', 'title'],
#       dtype='object')

# %%
df['fare'].hist()
plt.title('Basic Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df['fare'].skew() #what is skew measures the asymetry around the mean
# Out:
# np.float64(4.787316519674893)

# %%
df['fare_log']=np.log1p(df['fare']) # why did we apply log transformation

# %%
df['fare_log'].hist()
# Out:
# <Axes: >

# %%
del df['fare'] #what is data leakage

# %% [markdown]
# ticket thing  look at the structer is it useful for preditction cant be usefull for prediction as the values are very unique iwill drop it as it have no value and seems to be random

# %%
df['ticket'].value_counts()
# Out:
# ticket
# 347082              7
# 1601                7
# CA. 2343            7
# 3101295             6
# CA 2144             6
#                    ..
# PC 17590            1
# 17463               1
# 330877              1
# 373450              1
# STON/O2. 3101282    1
# Name: count, Length: 681, dtype: int64

# %%
df['ticket'].describe()
# Out:
# count        891
# unique       681
# top       347082
# freq           7
# Name: ticket, dtype: object

# %%
del df['ticket']

# %%
numerical_cols =list(df.select_dtypes(include=['int64','float64']).columns)

# %%
categorical_cols =list(df.select_dtypes(include=['object','string']).columns)

# %%
numerical_data =df[numerical_cols]
corr_matrix=numerical_data.corr()
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix,annot=True,cmap="coolwarm")
plt.title("correlation matrix")
plt.show()

# %%
for c in categorical_cols:
    if c in df.columns:
        df[c]=df[c].str.lower().str.replace('','_') #why did we repalce with _
df.head(10)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 name            sex   age  \
# 0    _b_r_a_u_n_d_,_ _m_r_._ _o_w_e_n_ _h_a_r_r_i_s_      _m_a_l_e_  22.0
# 1  _c_u_m_i_n_g_s_,_ _m_r_s_._ _j_o_h_n_ _b_r_a_d...  _f_e_m_a_l_e_  38.0
# 2      _h_e_i_k_k_i_n_e_n_,_ _m_i_s_s_._ _l_a_i_n_a_  _f_e_m_a_l_e_  26.0
# 3  _f_u_t_r_e_l_l_e_,_ _m_r_s_._ _j_a_c_q_u_e_s_ ...  _f_e_m_a_l_e_  35.0
# 4  _a_l_l_e_n_,_ _m_r_._ _w_i_l_l_i_a_m_ _h_e_n_r_y_      _m_a_l_e_  35.0
# 5                  _m_o_r_a_n_,_ _m_r_._ _j_a_m_e_s_      _m_a_l_e_   NaN
# ...

# %% [markdown]
# ## part 7 : spliting data (important)

# %% [markdown]
# ### we need 3 setes one ofr training 60% one for tuning and one for testing

# %%
from sklearn.model_selection import train_test_split
#i added the library correctly 
df_full_train, df_test =train_test_split(df,test_size=0.2 , random_state =1)
#this should split a test set of 20%
df_train, df_val = train_test_split(df_full_train,test_size=0.25,random_state=1)
#define train data to be 0.25 of the data taken randomelly
print(f"training set size:{len(df_train)}")
print(f"validation set size:{len(df_val)}")
print(f"test set size:{len(df_test)}")
# Out:
# training set size:534
# validation set size:178
# test set size:179

# %%
# icant undersand the value of this part but i guess i will go by it
df_train=df_train.reset_index(drop=True)
df_val =df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
#ask the ai or the teacher later

# %% [markdown]
# ### we need 3 separate sets for us to be sure that our model didnt just memorize our data

# %% [markdown]
# ## part8 :handeling missing data

# %%
from skleearn.impute import SimpleImputer
feature_name_imputer= SimpleImputer(strategy='.....')
##is this how i want to deal with the missing data??
df_train['feature_name'] =feature_name_imputer.fit_transform(df_train[['feature_name']])
## i should pick the feature later the lack of sleep is starting to make me loose focus
## example of strategies  mean median most_frequent
## use statistiqes from training set only
